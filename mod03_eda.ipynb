# %% [markdown]
# # Module 03: EDA

# %%
# packages
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
from sklearn.model_selection import train_test_split 
from ISLP import load_data

# set seed
seed = 2323

# %% [markdown]
# ### We'll use the _Hitters_ data from ISLP for this activity. The metadata for _Hitters_ can be found [here](https://intro-stat-learning.github.io/ISLP/datasets/Hitters.html).

# %%
# Load the data
Hitters = load_data('Hitters')

# %% [markdown]
# ### Determine the number of rows and columns in the dataset by returning its "shape" attribute

# %%
#fillin
Hitters.shape
# Out:
# (322, 20)

# %% [markdown]
# ### Determine whether each feature is numeric or categorical by returning the "dtype" attribute for each column

# %%
for col in Hitters.columns:
    print(f"Column: {col}, Dtype: {Hitters[col].dtype}")
# Out:
# Column: AtBat, Dtype: int64
# Column: Hits, Dtype: int64
# Column: HmRun, Dtype: int64
# Column: Runs, Dtype: int64
# Column: RBI, Dtype: int64
# Column: Walks, Dtype: int64
# Column: Years, Dtype: int64
# Column: CAtBat, Dtype: int64
# Column: CHits, Dtype: int64
# Column: CHmRun, Dtype: int64
# Column: CRuns, Dtype: int64
# Column: CRBI, Dtype: int64
# Column: CWalks, Dtype: int64
# Column: League, Dtype: category
# Column: Division, Dtype: category
# Column: PutOuts, Dtype: int64
# Column: Assists, Dtype: int64
# Column: Errors, Dtype: int64
# Column: Salary, Dtype: float64
# Column: NewLeague, Dtype: category

# %% [markdown]
# ### Before doing any other analyses, let's create training and test sets.

# %%
indepent_vars = ['CAtBat', 'CHits', 'CHmRun', 'CRuns', 'CRBI', 'CWalks']
X = Hitters[indepent_vars]
y = Hitters['Salary']


x_train, x_test, y_train, y_test, Train, Test = train_test_split(X, y, Hitters,
                               random_state=seed, 
                               test_size=0.40, 
                               shuffle=True)

# %% [markdown]
# ### Based on the metadata, what is the difference between the 6 columns starting with 'C' and the 6 related columns that don't?

# %% [markdown]
# Any columns starting with 'C' refers to his career stat while those that don't are his stats particular to a specfic time period (1986)

# %% [markdown]
# ### On the training set, create pairwise scatterplots for each of these 6 columns with the 'Salary' variable.

# %%
# Initialize the plots before drawing them
nrows = 3
ncols = 2
figsize = (5*nrows, 5*ncols)

fig, axes = subplots(nrows=nrows,
                     ncols=ncols,
                     figsize=figsize)

# Assign a grid location to each index
def range_to_grid(i, nrows, ncols):
    x=[]
    y=[]
    for n in range(nrows*ncols):
        x.append(n // ncols)
        y.append(n % ncols)
        # print(n,x[n],y[n]) # for testing this function
    return x[i],y[i]

# Plot the variables
for j in range(len(x_train.columns)):
    # print(range_to_grid(j,nrows,ncols)[0], range_to_grid(j,nrows,ncols)[1]) # testing
    axes[range_to_grid(j,nrows,ncols)[0],
         range_to_grid(j,nrows,ncols)[1]].plot(x_train.iloc[:,j], y_train, 'o')
    axes[range_to_grid(j,nrows,ncols)[0],
         range_to_grid(j,nrows,ncols)[1]].set_xlabel(x_train.columns[j])

# %% [markdown]
# ### Use the "describe" method to determine the mean, standard deviation, and 5 number summary of all numeric variables in the training subset of _Hitters_.

# %%
Train.describe()
# Out:
#             AtBat        Hits       HmRun        Runs         RBI       Walks  \
# count  193.000000  193.000000  193.000000  193.000000  193.000000  193.000000
# mean   381.829016  101.549223   10.150259   50.751295   47.093264   38.445596
# std    145.679181   44.267521    8.228711   24.784284   24.912589   21.136915
# min     19.000000    7.000000    0.000000    1.000000    2.000000    1.000000
# 25%    271.000000   68.000000    4.000000   32.000000   29.000000   22.000000
# 50%    369.000000   95.000000    8.000000   47.000000   43.000000   34.000000
# 75%    508.000000  136.000000   14.000000   68.000000   61.000000   53.000000
# max    687.000000  223.000000   40.000000  130.000000  121.000000  105.000000
#
#             Years        CAtBat        CHits      CHmRun        CRuns  \
# count  193.000000    193.000000   193.000000  193.000000   193.000000
# mean     7.253886   2587.440415   702.222798   59.668394   345.378238
# std      4.858712   2285.947344   649.010165   66.449102   322.848870
# min      1.000000     41.000000    13.000000    0.000000     3.000000
# 25%      3.000000    730.000000   185.000000   14.000000    98.000000
# 50%      6.000000   1876.000000   476.000000   36.000000   238.000000
# 75%     11.000000   3754.000000  1000.000000   78.000000   494.000000
# max     24.000000  14053.000000  4256.000000  315.000000  2165.000000
#
#               CRBI       CWalks      PutOuts     Assists      Errors  \
# count   193.000000   193.000000   193.000000  193.000000  193.000000
# mean    308.373057   248.388601   276.865285  105.300518    8.051813
# std     297.885894   250.777436   262.957701  137.135778    6.783667
# min       4.000000     4.000000     0.000000    0.000000    0.000000
# 25%      82.000000    63.000000   109.000000    7.000000    3.000000
# 50%     202.000000   166.000000   211.000000   38.000000    6.000000
# 75%     419.000000   332.000000   317.000000  173.000000   12.000000
# max    1348.000000  1566.000000  1320.000000  492.000000   32.000000
#
#             Salary
# count   164.000000
# mean    493.032951
# std     386.159522
# min      67.500000
# 25%     160.000000
# 50%     420.833500
# 75%     750.000000
# max    1925.571000

# %% [markdown]
# ### It looks like the mean and median of 'AtBat' are nearly equal. This _might_ suggest that this variable is normally distributed. Create a histogram of 'AtBat' to check this hypothesis.

# %%
#fillin
histogram = Train.hist('AtBat', bins=20)

# %% [markdown]
# ### Let's standardize the AtBat feature (i.e., normalize by z-scores). We'll create a new column in the training data called 'AtBat_st' to represent this.

# %%
Train['AtBat_st'] = (Train['AtBat'] - Train['AtBat'].mean()) / Train['AtBat'].std()

# %% [markdown]
# ### How many rows have an 'AtBat' value within the first standard deviation?
#
# Hint: the 'len' magic method returns the number of rows of a dataFrame.

# %%
count_within_one_std = len(Train[(Train['AtBat_st'] >= -1) & (Train['AtBat_st'] <= 1)])
count_within_one_std
# Out:
# 115

# %% [markdown]
# ### Going back to the results of the 'describe' method, how can you tell that the 'Salary' variable has missing values?

# %% [markdown]
# Count of Salary is less than the count of other variables

# %% [markdown]
# ### Describe a situation where a variable could have missing values but this would not be reflected in the results of the 'describe' method.

# %% [markdown]
# If those missing values were filled in with an value based on the values that are there during preprocess

# %% [markdown]
# ### On the training data, create separate boxplots of the 'AtBat' variable for when 'Salary' is populated or missing.

# %%
# Create boxplots for AtBat when Salary is missing vs populated
fig, axes = subplots(1, 2, figsize=(12, 5))

# Salary is missing
missing_salary = Train[Train['Salary'].isna()]
Train['NoSalary'] = Train['Salary'].isna()
axes[0].boxplot(missing_salary['AtBat'])
axes[0].set_title('AtBat when Salary is Missing')
axes[0].set_ylabel('AtBat')

# Salary is populated
has_salary = Train[Train['Salary'].notna()]
axes[1].boxplot(has_salary['AtBat'])
axes[1].set_title('AtBat when Salary is Populated')
axes[1].set_ylabel('AtBat')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a correlation matrix for all numeric features in the training set

# %%
Train.corr(numeric_only=True)
# Out:
#              AtBat      Hits     HmRun      Runs       RBI     Walks  \
# AtBat     1.000000  0.963324  0.540323  0.906579  0.798717  0.631824
# Hits      0.963324  1.000000  0.516853  0.914739  0.795316  0.605876
# HmRun     0.540323  0.516853  1.000000  0.618439  0.840613  0.385425
# Runs      0.906579  0.914739  0.618439  1.000000  0.786635  0.711346
# RBI       0.798717  0.795316  0.840613  0.786635  1.000000  0.553527
# CHits     0.883547  0.132818 -0.003372 -0.062669  0.629875  0.146763  0.019142
# CHmRun    0.750795  0.126756 -0.129640 -0.141514  0.616170  0.150166 -0.077971
# CRuns     0.915961  0.115081 -0.025653 -0.087724  0.649791  0.164892  0.016753
# CRBI      0.863891  0.153254 -0.050173 -0.087897  0.641038  0.145779 -0.028395
# CWalks    1.000000  0.104123 -0.046018 -0.107988  0.598203  0.056578  0.029898
# PutOuts   0.104123  1.000000 -0.011760  0.117335  0.314053  0.345879 -0.115112
# Assists  -0.046018 -0.011760  1.000000  0.716448 -0.005242  0.363085 -0.173300
# Errors   -0.107988  0.117335  0.716448  1.000000 -0.027683  0.368162 -0.234675
# Salary    0.598203  0.314053 -0.005242 -0.027683  1.000000  0.401390       NaN
# AtBat_st  0.056578  0.345879  0.363085  0.368162  0.401390  1.000000 -0.264561
# NoSalary  0.029898 -0.115112 -0.173300 -0.234675       NaN -0.264561  1.000000

# %% [markdown]
# ### Propose two different ways of imputing the missing values of Salary while taking advantage of the information given in the boxplots or the correlation matrix.

# %% [markdown]
# **Method 1: Regression Imputation** - Use the correlation matrix to identify the features most strongly correlated with Salary (likely CAtBat, CHits, CRuns, CRBI). Build a linear regression model on the complete cases and use the predicted values to impute the missing Salary values.
#
# **Method 2: Conditional Mean Imputation based on AtBat Groups** - Use the boxplot analysis showing the relationship between AtBat and Salary. Group players by AtBat quartiles and impute missing Salary values with the mean Salary of players in the same AtBat group who have non-missing Salary values.

# %% [markdown]
# ### For our last exercise, we'll explore Hits and Walks relative to AtBat totals.
# - Use the sum function to calculuate the totals of each of these three variables for the 1986 season (on the training set).
# - Create a pie chart which shows total hits, total walks, and remaining total (neither) as percents of the At Bats total (on the training set).

# %%
TotHits = Train['Hits'].sum()
TotWalks = Train['Walks'].sum()
TotAtBat = Train['AtBat'].sum()

Labels = ['Hits', 'Walks', 'Neither']
Totals = [TotHits, TotWalks, TotAtBat-TotHits-TotWalks]

# %%
# pie chart
plt.pie(Totals, labels=Labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of At-Bat Outcomes (1986 Training Set)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ### The previous two cells gave us totals across all players. For each player in the training set, calculate the Hits as a percent of AtBat and store it in a new variable called 'AVG'

# %%
Train['AVG'] = Train['Hits'] / Train['AtBat']

# %% [markdown]
# ### Using 0.25 and 0.31 as the split points, create a new variable with three bins: high, medium, and low.

# %%
Train['AVG_bin'] = 'medium'
Train.loc[Train['AVG'] < 0.25, 'AVG_bin'] = 'low'
Train.loc[Train['AVG'] > 0.31, 'AVG_bin'] = 'high'

# %% [markdown]
# ### Create a bar chart that displays the number of players in each of the low, medium, and high categories (for the training data).

# %%
Train['AVG_bin'].value_counts()
# Out:
# AVG_bin
# medium    114
# low        65
# high       14
# Name: count, dtype: int64

# %% [markdown]
# Notice that the order of the bars will be medium, low, high. That's counterintuitive. We can reorder these quickly.

# %%
indexMap = ['low', 'medium', 'high']
reordered_list = [Train['AVG_bin'].value_counts()[i] for i in indexMap]

# %%
plt.bar(indexMap, reordered_list)

plt.title("1986 AVG (Training Set)")
plt.ylabel("Number of Players")

plt.xticks(indexMap)

plt.show()

# %% [markdown]
# ### Did we use the depth method or width method for creating these bins? Explain.

# %% [markdown]
# We used the width method, this is indicated by the usage of fixed, predefined cutoff points and how the bins vary from each in terms of number of players
